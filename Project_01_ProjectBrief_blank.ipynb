# %% [markdown]
# # Project 1: Explanatory Data Analysis & Data Presentation (Movies Dataset)

# %% [markdown]
# # Project Brief for Self-Coders

# %% [markdown]
# Here you´ll have the opportunity to code major parts of Project 1 on your own. If you need any help or inspiration, have a look at the Videos or the Jupyter Notebook with the full code. <br> <br>
# Keep in mind that it´s all about __getting the right results/conclusions__. It´s not about finding the identical code. Things can be coded in many different ways. Even if you come to the same conclusions, it´s very unlikely that we have the very same code.

# %% [markdown]
# ## Data Import and first Inspection

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %% [markdown]
# __Some additional information on Features/Columns__:

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('./movies_complete.csv')
df.head()
# Out:
# C:\Users\Harsh\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# ...

# %%
df.release_date = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %% [markdown]
# ## The best and the worst movies...

# %% [markdown]
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the

# %% [markdown]
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity

# %% [markdown]
# __Define__ an appropriate __user-defined function__ to reuse code.

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
df.sort_values(by='revenue_musd',ascending=False).head()
# Out:
#            id                         title  \
# 14448   19995                        Avatar
# 26265  140607  Star Wars: The Force Awakens
# 1620      597                       Titanic
# 17669   24428                  The Avengers
# 24812  135397                Jurassic World
#
#                                          tagline release_date  \
# 14448                Enter the World of Pandora.   2009-12-10
# 26265              Every generation has a story.   2015-12-15
# 1620   Nothing on Earth could come between them.   1997-11-18
# 17669                    Some assembly required.   2012-04-25
# 24812                          The park is open.   2015-06-09
#
#                                           genres     belongs_to_collection  \
# 14448   Action|Adventure|Fantasy|Science Fiction         Avatar Collection
# 26265   Action|Adventure|Science Fiction|Fantasy      Star Wars Collection
# 1620                      Drama|Romance|Thriller                       NaN
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
df.sort_values(by='budget_musd',ascending=False).head()
# Out:
#           id                                        title  \
# 16986   1865  Pirates of the Caribbean: On Stranger Tides
# 11743    285     Pirates of the Caribbean: At World's End
# 26268  99861                      Avengers: Age of Ultron
# 10985   1452                             Superman Returns
# 18517  49529                                  John Carter
#
#                                               tagline release_date  \
# 16986                     Live Forever Or Die Trying.   2011-05-14
# 11743  At the end of the world, the adventure begins.   2007-05-19
# 26268                             A New Age Has Come.   2015-04-22
# 10985                                             NaN   2006-06-28
# 18517            Lost in our world, found in another.   2012-03-07
#
#                                          genres  \
# 16986                  Adventure|Action|Fantasy
# 11743                  Adventure|Fantasy|Action
# 26268          Action|Adventure|Science Fiction
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
df['profit'] = df['revenue_musd'] - df['budget_musd']
df.sort_values(by='profit',ascending=False)
# Out:
#            id                         title  \
# 14448   19995                        Avatar
# 26265  140607  Star Wars: The Force Awakens
# 1620      597                       Titanic
# 24812  135397                Jurassic World
# 28501  168259                     Furious 7
# ...       ...                           ...
# 44686  439050                        Subdue
# 44687  111109           Century of Birthing
# 44688   67758                      Betrayal
# 44689  227506              Satan Triumphant
# 44690  461257                      Queerama
#
#                                           tagline release_date  \
# 14448                 Enter the World of Pandora.   2009-12-10
# 26265               Every generation has a story.   2015-12-15
# 1620    Nothing on Earth could come between them.   1997-11-18
# 24812                           The park is open.   2015-06-09
# 28501                         Vengeance Hits Home   2015-04-01
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
df.sort_values(by='profit',ascending=True).head()
# Out:
#            id                                        title  \
# 20959   57201                              The Lone Ranger
# 7164    10733                                    The Alamo
# 16659   50321                              Mars Needs Moms
# 43611  339964  Valerian and the City of a Thousand Planets
# 2684     1911                             The 13th Warrior
#
#                          tagline release_date  \
# 20959    Never Take Off the Mask   2013-07-03
# 7164       You will never forget   2004-04-07
# 16659  Mom needs a little space.   2011-03-09
# 43611                        NaN   2017-07-20
# 2684        Prey for the living.   1999-08-27
#
#                                  genres belongs_to_collection  \
# 20959          Action|Adventure|Western                   NaN
# 7164                Western|History|War                   NaN
# 16659        Adventure|Animation|Family                   NaN
# 43611  Adventure|Science Fiction|Action                   NaN
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
df['ROI'] = df['revenue_musd']/df['budget_musd']
df[df['budget_musd']>= 10].sort_values(by='ROI',ascending=False)
# Out:
#            id                       title  \
# 1055      601  E.T. the Extra-Terrestrial
# 255        11                   Star Wars
# 588       114                Pretty Woman
# 18300   77338            The Intouchables
# 1144     1891     The Empire Strikes Back
# ...       ...                         ...
# 44240    2331                       Jesus
# 44272  460846                    Security
# 44348  301016                   Sunstroke
# 44439  407448                     Detroit
# 44570  248705  The Visitors: Bastille Day
#
#                                                  tagline release_date  \
# 1055   He is afraid. He is alone. He is three million...   1982-04-03
# 255         A long time ago in a galaxy far, far away...   1977-05-25
# 588          Who knew it was so much fun to be a hooker?   1990-03-23
# 18300  Sometimes you have to reach into someone else'...   2011-11-02
# 1144                          The Adventure Continues...   1980-05-17
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
df[df['budget_musd']>= 10].sort_values(by='ROI',ascending=True).head()
# Out:
#           id            title  \
# 6955   14844  Chasing Liberty
# 8041   18475      The Cookout
# 17381  33927         Deadfall
# 6678   10944       In the Cut
# 20015  98339    The Samaritan
#
#                                                  tagline release_date  \
# 6955   How do you fall in love with the whole world w...   2004-01-09
# 8041                     This summer, get your grill on!   2004-09-03
# 17381                                ...The ultimate con   1993-10-08
# 6678     Everything you know about desire is dead wrong.   2003-09-09
# 20015                                                NaN   2012-03-02
#
#                      genres belongs_to_collection original_language  \
# 6955         Comedy|Romance                   NaN                en
# 8041           Comedy|Drama                   NaN                en
# 17381  Crime|Drama|Thriller                   NaN                en
# 6678       Mystery|Thriller                   NaN                en
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director', 'profit', 'ROI'],
#       dtype='object')

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
df.sort_values(by='vote_count',ascending = False).head()
# Out:
#            id            title                                  tagline  \
# 15368   27205        Inception     Your mind is the scene of the crime.
# 12396     155  The Dark Knight                          Why So Serious?
# 14448   19995           Avatar              Enter the World of Pandora.
# 17669   24428     The Avengers                  Some assembly required.
# 26272  293660         Deadpool  Witness the beginning of a happy ending
#
#       release_date                                             genres  \
# 15368   2010-07-14  Action|Thriller|Science Fiction|Mystery|Adventure
# 12396   2008-07-16                        Drama|Action|Crime|Thriller
# 14448   2009-12-10           Action|Adventure|Fantasy|Science Fiction
# 17669   2012-04-25                   Science Fiction|Action|Adventure
# 26272   2016-02-09                            Action|Adventure|Comedy
#
#             belongs_to_collection original_language  budget_musd  \
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
df[df['vote_count']>50].sort_values(by='vote_average',ascending=False).head()
# Out:
#            id                                          title  \
# 10233   19404                    Dilwale Dulhania Le Jayenge
# 38503  192040                                   Planet Earth
# 7578    20532                             Sansho the Bailiff
# 28846  321640  The Jinx: The Life and Deaths of Robert Durst
# 32987  359364                                          Human
#
#                                                  tagline release_date  \
# 10233                               Come... Fall In Love   1995-10-20
# 38503        planet earth as you've never seen it before   2006-12-10
# 7578   A film of unparalleled beauty by the great Jap...   1954-03-31
# 28846  Four Decades. Three Murders. And One Very Rich...   2015-02-08
# 32987  Accepting your true identity is accepting who ...   2015-09-12
#
#                      genres belongs_to_collection original_language  \
# 10233  Comedy|Drama|Romance                   NaN                hi
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
df[df['vote_count']>100].sort_values(by='vote_average',ascending=True).head()
# Out:
#           id                 title  \
# 6665   11059     House of the Dead
# 13476  14164  Dragonball Evolution
# 3439    5491     Battlefield Earth
# 9578   12142     Alone in the Dark
# 12824  13805        Disaster Movie
#
#                                                  tagline release_date  \
# 6665                           You won't last the night.   2003-04-11
# 13476                          The legend comes to life.   2009-04-01
# 3439                                Take Back The Planet   2000-05-10
# 9578   Can mankind defeat the army of darkness unleas...   2005-01-28
# 12824    Your favorite movies are going to be destroyed.   2008-08-29
#
#                                                   genres  \
# 6665                              Horror|Action|Thriller
# 13476  Action|Adventure|Fantasy|Science Fiction|Thriller
# 3439                          Action|Science Fiction|War
# 9578                      Action|Fantasy|Horror|Thriller
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
df.sort_values(by='popularity',ascending=False).head()
# Out:
#            id                 title  \
# 30330  211672               Minions
# 32927  297762          Wonder Woman
# 41556  321612  Beauty and the Beast
# 42940  339403           Baby Driver
# 24187  177572            Big Hero 6
#
#                                               tagline release_date  \
# 30330    Before Gru, they had a history of bad bosses   2015-06-17
# 32927                   Power. Grace. Wisdom. Wonder.   2017-05-30
# 41556                                   Be our guest.   2017-03-16
# 42940               All you need is one killer track.   2017-06-28
# 24187  From the creators of Wreck-it Ralph and Frozen   2014-10-24
#
#                                          genres     belongs_to_collection  \
# 30330         Family|Animation|Adventure|Comedy  Despicable Me Collection
# 32927                  Action|Adventure|Fantasy   Wonder Woman Collection
# 41556                    Family|Fantasy|Romance                       NaN
# ...

# %% [markdown]
# ## Find your next Movie

# %% [markdown]
# 3. __Filter__ the Dataset for movies that meet the following conditions:

# %% [markdown]
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %% [markdown]
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %% [markdown]
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %% [markdown]
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %%
df['genres'][0]
mask_genres = df.genres.str.contains('Action') & df.genres.str.contains('Science Fiction')
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
mask_actor = df.cast.str.contains('Bruce Willis')
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.loc[mask_actor & mask_genres,['title','vote_average']].sort_values(by = 'vote_average',ascending = False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element           7.3
# 19218                 Looper           6.6
# 1786              Armageddon           6.5
# 14135             Surrogates           5.9
# 20333  G.I. Joe: Retaliation           5.4
# 27619                   Vice           4.1

# %%
mask_actor = df.cast.str.contains('Uma Thurman')
mask_director=  df.director.str.contains('Quentin Tarantino')

# %%
df.loc[mask_actor & mask_director,['title','vote_average','runtime']].sort_values(by = 'runtime',ascending = True)
# Out:
#                   title  vote_average  runtime
# 6667  Kill Bill: Vol. 1           7.7    111.0
# 7208  Kill Bill: Vol. 2           7.7    136.0
# 291        Pulp Fiction           8.3    154.0

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director', 'profit', 'ROI'],
#       dtype='object')

# %%
mask_studio = df.production_companies.str.contains('Pixar').fillna(False)
mask_time = df.release_date.between('2010-01-01','2015-12-31')

# %%
pixar = df.loc[mask_studio & mask_time,['title','poster_path','revenue_musd','release_date']].sort_values(by='revenue_musd')

# %%
pixar
# Out:
#                             title  \
# 30388           The Good Dinosaur
# 18900                       Brave
# 17220                      Cars 2
# 20888         Monsters University
# 29957                  Inside Out
# 15236                 Toy Story 3
# 16392                 Day & Night
# 21694           The Blue Umbrella
# 21697        Toy Story of Terror!
# 22489                     La luna
# 24252           Hawaiian Vacation
# 24254                   Small Fry
# 25515             Partysaurus Rex
# 25516        The Legend of Mor'du
# 25517  Toy Story That Time Forgot
# 31803                        Lava
# 34560         Sanjay's Super Team
# 40259                   Air Mater
# 40675         Riley's First Date?
#
#                                              poster_path  revenue_musd  \
# 30388  <img src='http://image.tmdb.org/t/p/w185//8RSk...    331.926147
# 18900  <img src='http://image.tmdb.org/t/p/w185//8l0p...    538.983207
# ...

# %%
mask_genres = df.genres.str.contains('Action') & df.genres.str.contains('Thriller')
language = df.original_language.str.contains('en')
ratings = df.vote_average >= 7.5

# %%
movies = df.loc[mask_genres & language &ratings,['title']]

# %%
movies
# Out:
#                                     title
# 5                                    Heat
# 425                         Carlito's Way
# 549                          True Romance
# 580            Terminator 2: Judgment Day
# 662                    Hostile Intentions
# 998                              Die Hard
# 1148                               Aliens
# 1161                                Alien
# 2585                          The Killing
# 3216                   The Asphalt Jungle
# 3235   The Taking of Pelham One Two Three
# 3606                       Bound by Honor
# 4098                             Scarface
# 7001                 To Have and Have Not
# 7208                    Kill Bill: Vol. 2
# 7404              The Internecine Project
# 8268                             Scarface
# 8707                             Sorcerer
# 10758                      V for Vendetta
# 11932                      Illegal Tender
# 12396                     The Dark Knight
# ...

# %% [markdown]
# ## Are Franchises more successful?

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df['collection'] = df['belongs_to_collection'].map(lambda x: 'no' if pd.isnull(x) else 'yes')

# %%
df['collection']
# Out:
# 0        yes
# 1         no
# 2        yes
# 3         no
# 4        yes
#         ...
# 44686     no
# 44687     no
# 44688     no
# 44689     no
# 44690     no
# Name: collection, Length: 44691, dtype: object

# %%
df.groupby(by='collection').agg({'revenue_musd': pd.Series.mean})
# Out:
#             revenue_musd
# collection
# no             44.742814
# yes           165.708193

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df.groupby(by='collection').agg({'ROI': pd.Series.median})
# Out:
#                  ROI
# collection
# no          1.619699
# yes         3.709195

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby(by='collection').agg({'budget_musd': pd.Series.mean})
# Out:
#             budget_musd
# collection
# no            18.047741
# yes           38.319847

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby(by='collection').agg({'popularity': pd.Series.mean})
# Out:
#             popularity
# collection
# no            2.592726
# yes           6.245051

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby(by='collection').agg({'vote_average': pd.Series.mean})
# Out:
#             vote_average
# collection
# no              6.008787
# yes             5.956806

# %% [markdown]
# ## Most Successful Franchises

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.groupby(by='belongs_to_collection').count().sort_values(by='id',ascending=False)
# Out:
#                                             id  title  tagline  release_date  \
# belongs_to_collection
# The Bowery Boys                             29     29       24            29
# Totò Collection                             27     27        2            27
# James Bond Collection                       26     26       26            26
# Zatôichi: The Blind Swordsman               26     26        1            26
# The Carry On Collection                     25     25       18            25
# ...                                         ..    ...      ...           ...
# Göta kanal collection                        1      1        0             1
# Hailey Dean Mystery Collection               1      1        0             1
# The Adventures of Mickey Matson Collection   1      1        0             1
# The 1997 Trilogy                             1      1        0             1
# Flesh Gordon Collection                      1      1        1             1
#
# ...

# %%
df.groupby(by='belongs_to_collection').agg({'budget_musd':pd.Series.sum}).sort_values(by='budget_musd',ascending=False)
# Out:
#                                      budget_musd
# belongs_to_collection
# James Bond Collection                    1539.65
# Harry Potter Collection                  1280.00
# Pirates of the Caribbean Collection      1250.00
# The Fast and the Furious Collection      1009.00
# X-Men Collection                          983.00
# ...                                          ...
# Little Bear                                 0.00
# Lilla Jönsonligan Collection                0.00
# Library Wars Collection                     0.00
# Lezioni di Cioccolato Collection            0.00
# 식객 시리즈                                      0.00
#
# [1691 rows x 1 columns]

# %%
df.groupby(by='belongs_to_collection').agg({'budget_musd':pd.Series.mean}).sort_values(by='budget_musd',ascending=False)
# Out:
#                                      budget_musd
# belongs_to_collection
# Tangled Collection                         260.0
# The Avengers Collection                    250.0
# Pirates of the Caribbean Collection        250.0
# The Hobbit Collection                      250.0
# Man of Steel Collection                    237.5
# ...                                          ...
# Параграф 78 - Дилогия                        NaN
# Сказки Чуковского                            NaN
# Чебурашка и крокодил Гена                    NaN
# 男はつらいよ シリーズ                                  NaN
# 식객 시리즈                                       NaN
#
# [1691 rows x 1 columns]

# %%
df.groupby(by='belongs_to_collection').agg({'revenue_musd':pd.Series.sum}).sort_values(by='revenue_musd',ascending=False)
# Out:
#                                       revenue_musd
# belongs_to_collection
# Harry Potter Collection                7707.367425
# Star Wars Collection                   7434.494790
# James Bond Collection                  7106.970239
# The Fast and the Furious Collection    5125.098793
# Pirates of the Caribbean Collection    4521.576826
# ...                                            ...
# Les Profs                                 0.000000
# Les Mystères de l'ouest (Collection)      0.000000
# Les Charlots - Saga                       0.000000
# Les Boys                                  0.000000
# 식객 시리즈                                    0.000000
#
# [1691 rows x 1 columns]

# %%
df.groupby(by='belongs_to_collection').agg({'revenue_musd':pd.Series.mean}).sort_values(by='revenue_musd',ascending=False)
# Out:
#                                  revenue_musd
# belongs_to_collection
# Avatar Collection                 2787.965087
# The Avengers Collection           1462.480802
# Frozen Collection                 1274.219009
# Finding Nemo Collection            984.453213
# The Hobbit Collection              978.507785
# ...                                       ...
# Сказки Чуковского                         NaN
# Чебурашка и крокодил Гена                 NaN
# Что Творят мужчины! (Коллекция)           NaN
# 男はつらいよ シリーズ                               NaN
# 식객 시리즈                                    NaN
#
# [1691 rows x 1 columns]

# %%
df.groupby(by='belongs_to_collection').agg({'vote_average':pd.Series.mean}).sort_values(by='vote_average',ascending=False)
# Out:
#                                      vote_average
# belongs_to_collection
# Argo Collection                               9.3
# Kenji Misumi's Trilogy of the Sword           9.0
# Dreileben                                     9.0
# Bloodfight                                    9.0
# Алиса в стране чудес (Коллекция)              8.7
# ...                                           ...
# The Aum Shinrikyo Collection                  NaN
# The Pub Landlord Collection                   NaN
# Thou Shalt Laugh Collection                   NaN
# Tomtar och Trolltyg Collection                NaN
# Wodehouse P.G. Collection                     NaN
#
# [1691 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director', 'profit', 'ROI', 'collection'],
#       dtype='object')

# %% [markdown]
# ## Most Successful Directors

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.groupby(by='director').count().sort_values(by='id',ascending=False)
# Out:
#                   id  title  tagline  release_date  genres  \
# director
# John Ford         66     66       42            66      65
# Michael Curtiz    65     65       47            65      65
# Werner Herzog     54     54       15            54      54
# Alfred Hitchcock  53     53       35            53      52
# Woody Allen       49     49       23            49      49
# ...               ..    ...      ...           ...     ...
# Jason Zada         1      1        1             1       1
# Jasper James       1      1        1             1       1
# Javier Aguirre     1      1        1             1       1
# Javier Balaguer    1      1        0             1       1
# 진모영                1      1        0             1       1
#
#                   belongs_to_collection  original_language  budget_musd  \
# director
# John Ford                             1                 66           13
# Michael Curtiz                        0                 65            7
# ...

# %%
df.groupby(by='director').agg({'revenue_musd':pd.Series.sum}).sort_values(by='revenue_musd',ascending=False)
# Out:
#                   revenue_musd
# director
# Steven Spielberg   9256.621422
# Peter Jackson      6528.244659
# Michael Bay        6437.466781
# James Cameron      5900.610310
# David Yates        5334.563196
# ...                        ...
# Héctor Olivera        0.000000
# Hélène Fillières      0.000000
# Héléna Klotz          0.000000
# I. Robert Levy        0.000000
# 진모영                   0.000000
#
# [17349 rows x 1 columns]

# %%
df.groupby(by='director').agg({'vote_average':pd.Series.mean}).sort_values(by='vote_average',ascending=False)
# Out:
#                      vote_average
# director
# David Langlitz               10.0
# Joerg Steineck               10.0
# Cody Blue Snider             10.0
# Mohammad-Ali Talebi          10.0
# Hemant Gaba                  10.0
# ...                           ...
# Yulin Kuang                   NaN
# Yuliya Solntseva              NaN
# Zion Myers                    NaN
# fraser Watson                 NaN
# Вера Кричевская               NaN
#
# [17349 rows x 1 columns]

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director', 'profit', 'ROI', 'collection'],
#       dtype='object')

# %%
df.set_index('id',inplace=True)

# %%
df
# Out:
#                               title  \
# id
# 862                       Toy Story
# 8844                        Jumanji
# 15602              Grumpier Old Men
# 31357             Waiting to Exhale
# 11862   Father of the Bride Part II
# ...                             ...
# 439050                       Subdue
# 111109          Century of Birthing
# 67758                      Betrayal
# 227506             Satan Triumphant
# 461257                     Queerama
#
#                                                   tagline release_date  \
# id
# 862                                                   NaN   1995-10-30
# 8844            Roll the dice and unleash the excitement!   1995-12-15
# 15602   Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 31357   Friends are the people who let you be yourself...   1995-12-22
# 11862   Just When His World Is Back To Normal... He's ...   1995-02-10
# ...                                                   ...          ...
# ...

# %%
df.cast.str.split('|')
# Out:
# id
# 862       [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 8844      [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 15602     [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 31357     [Whitney Houston, Angela Bassett, Loretta Devi...
# 11862     [Steve Martin, Diane Keaton, Martin Short, Kim...
#                                 ...
# 439050          [Leila Hatami, Kourosh Tahami, Elham Korda]
# 111109    [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 67758     [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 227506    [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 461257                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
act = df.cast.str.split('|',expand=True)
act
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act.stack().reset_index(level = 1,drop = True).to_frame()
# Out:
#                         0
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act = act.stack().reset_index(level = 1,drop = True).to_frame()

# %%
act.columns = ['Actor']

# %%
act
# Out:
#                     Actor
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act = act.merge(df[['title','revenue_musd','vote_average','popularity']],
               how='left',left_index=True,right_index=True)

# %%
act
# Out:
#                     Actor             title  revenue_musd  vote_average  \
# id
# 862             Tom Hanks         Toy Story    373.554033           7.7
# 862             Tim Allen         Toy Story    373.554033           7.7
# 862           Don Rickles         Toy Story    373.554033           7.7
# 862            Jim Varney         Toy Story    373.554033           7.7
# 862         Wallace Shawn         Toy Story    373.554033           7.7
# ...                   ...               ...           ...           ...
# 227506   Iwan Mosschuchin  Satan Triumphant           NaN           NaN
# 227506  Nathalie Lissenko  Satan Triumphant           NaN           NaN
# 227506       Pavel Pavlov  Satan Triumphant           NaN           NaN
# 227506  Aleksandr Chabrov  Satan Triumphant           NaN           NaN
# 227506        Vera Orlova  Satan Triumphant           NaN           NaN
#
#         popularity
# id
# 862      21.946943
# 862      21.946943
# 862      21.946943
# ...

# %%
act.Actor.nunique()
# Out:
# 201501

# %%
act.Actor.value_counts().head(20)
# Out:
# Actor
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# John Carradine        109
# Gérard Depardieu      109
# Jackie Chan           108
# Donald Sutherland     108
# Frank Welker          107
# Robert De Niro        104
# Danny Trejo           101
# Steve Buscemi         101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Dennis Hopper          92
# Susan Sarandon         92
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,8))
act.Actor.value_counts().head(20).plot(kind='bar',fontsize=15)
plt.title('Most Active Actors',fontsize=20)
plt.ylabel('Number of Movies',fontsize=15)
plt.show()

# %%
agg = act.groupby('Actor').agg(Total_Revenue = ('revenue_musd','sum'),
                               Mean_Average = ('revenue_musd','mean'),
                               Mean_Rating = ('vote_average','mean'),
                               Mean_Pop = ('popularity','mean'),
                               Total_Movies = ('Actor','count'))

# %%
agg.nlargest(10,'Total_Movies')
# Out:
#                    Total_Revenue  Mean_Average  Mean_Rating   Mean_Pop  \
# Actor
# Bess Flowers          368.913259     14.756530     6.184186   2.030528
# Christopher Lee      9417.047887    324.725789     5.910204   4.749606
# John Wayne            236.094000     11.242571     5.712097   3.092939
# Samuel L. Jackson   17109.620672    213.870258     6.266116  11.703945
# Michael Caine        8053.404838    191.747734     6.269444   8.265272
# Gérard Depardieu     1247.608953     95.969919     6.053211   3.703836
# John Carradine        255.839586     19.679968     5.546667   2.434950
# Donald Sutherland    5390.766679    138.224787     6.233962   7.003230
# Jackie Chan          4699.185933    146.849560     6.275701   5.862638
# Frank Welker        13044.152470    326.103812     6.310377   9.571404
#
#                    Total_Movies
# Actor
# Bess Flowers                240
# Christopher Lee             148
# John Wayne                  125
# Samuel L. Jackson           122
# ...

# %%
agg.nlargest(10,'Total_Revenue')
# Out:
#                    Total_Revenue  Mean_Average  Mean_Rating   Mean_Pop  \
# Actor
# Stan Lee            19414.957555    647.165252     6.513043  29.936175
# Samuel L. Jackson   17109.620672    213.870258     6.266116  11.703945
# Warwick Davis       13256.032188    662.801609     6.294118  13.088614
# Frank Welker        13044.152470    326.103812     6.310377   9.571404
# John Ratzenberger   12596.126073    449.861645     6.484444  10.959477
# Jess Harnell        12234.608163    611.730408     6.435294  10.919015
# Hugo Weaving        11027.578473    459.482436     6.473684  10.967890
# Ian McKellen        11015.592318    478.938796     6.353488  15.447180
# Johnny Depp         10653.760641    217.423687     6.440580  12.378196
# Alan Rickman        10612.625348    353.754178     6.715556  10.399285
#
#                    Total_Movies
# Actor
# Stan Lee                     48
# Samuel L. Jackson           122
# Warwick Davis                34
# Frank Welker                107
# ...

# %%
agg[agg['Total_Movies']>10].nlargest(10,'Mean_Average')
# Out:
#                   Total_Revenue  Mean_Average  Mean_Rating   Mean_Pop  \
# Actor
# Gloria Stuart       1845.034188   1845.034188     6.368750   3.477432
# Keith Richards      2967.713802    989.237934     6.463636   5.032988
# James Cameron       1862.075059    931.037530     7.063636   4.691718
# Matthew Lewis       7915.312500    879.479167     7.372727  23.097479
# Luke de Woolfson    1720.671036    860.335518     5.718182   8.767206
# Yuri Lowenthal      1708.162716    854.081358     6.188235  19.884649
# Dominic Monaghan    3289.607607    822.401902     6.045455  10.621675
# Peter Mayhew        4820.721631    803.453605     6.700000  12.303552
# Victoria De Mare     783.112979    783.112979     5.058333  17.606919
# Alex Zahara          769.653595    769.653595     5.958824   5.087243
#
#                   Total_Movies
# Actor
# Gloria Stuart               18
# Keith Richards              23
# James Cameron               12
# Matthew Lewis               11
# ...

# %%
agg[agg['Total_Movies']>20].nlargest(10,'Mean_Rating')
# Out:
#                    Total_Revenue  Mean_Average  Mean_Rating  Mean_Pop  \
# Actor
# Maaya Sakamoto        128.577685     21.429614     7.339286  3.844869
# Kemal Sunal             0.698200      0.698200     7.295238  0.572455
# Kamatari Fujiwara       0.327081      0.163541     7.254545  3.998702
# Alfred Hitchcock      163.404055     13.617005     7.241667  8.793663
# Toshirō Mifune         32.124151     10.708050     7.235000  3.990092
# Tatsuya Nakadai         4.341494      2.170747     7.188235  3.188137
# Colin Kenny            49.385846      9.877169     7.119048  4.685666
# Eitarô Ozawa            4.100000      4.100000     7.115000  1.029473
# Eijirô Tôno            29.820132     14.910066     7.093750  2.853840
# Chishu Ryu              0.502758      0.502758     7.084444  1.432507
#
#                    Total_Movies
# Actor
# Maaya Sakamoto               28
# Kemal Sunal                  21
# Kamatari Fujiwara            23
# Alfred Hitchcock             24
# ...

# %%
agg[agg['Total_Movies']>20].nlargest(10,'Mean_Pop')
# Out:
#                  Total_Revenue  Mean_Average  Mean_Rating   Mean_Pop  \
# Actor
# Jon Hamm           3449.345393    191.630300     6.328000  39.417351
# Ava Acres          6272.358330    482.489102     5.985714  36.260864
# Stan Lee          19414.957555    647.165252     6.513043  29.936175
# Hiroyuki Sanada    2732.114541    227.676212     6.141667  29.300654
# T.J. Miller        4589.338627    269.961096     6.191304  26.806334
# Geoffrey Rush      8531.131294    304.683261     6.573810  26.354113
# Steve Carell       6979.516101    240.672969     6.258824  25.930487
# Jon Bernthal       2140.756551    152.911182     6.400000  23.369757
# Sandra Bullock     4902.157476    181.561388     5.994737  22.489001
# Zoe Saldana        7206.979916    300.290830     6.461765  21.112548
#
#                  Total_Movies
# Actor
# Jon Hamm                   25
# Ava Acres                  21
# Stan Lee                   48
# Hiroyuki Sanada            24
# T.J. Miller                23
# ...

# %%
action = df.genres.str.contains('Action')

# %%
vote = df.vote_count > 100
vote
# Out:
# id
# 862        True
# 8844       True
# 15602     False
# 31357     False
# 11862      True
#           ...
# 439050    False
# 111109    False
# 67758     False
# 227506    False
# 461257    False
# Name: vote_count, Length: 44691, dtype: bool

# %%
df.columns
# Out:
# Index(['title', 'tagline', 'release_date', 'genres', 'belongs_to_collection',
#        'original_language', 'budget_musd', 'revenue_musd',
#        'production_companies', 'production_countries', 'vote_count',
#        'vote_average', 'popularity', 'runtime', 'overview', 'spoken_languages',
#        'poster_path', 'cast', 'cast_size', 'crew_size', 'director', 'profit',
#        'ROI', 'collection'],
#       dtype='object')

# %%
date = df.release_date.between('1990-01-01','1999-12-31')

# %%
df.loc[action & date &vote , ['title','release_date','vote_count','vote_average']].sort_values(by='vote_average',ascending=False)
# Out:
#                                title release_date  vote_count  vote_average
# id
# 603                       The Matrix   1999-03-30      9079.0           7.9
# 9323              Ghost in the Shell   1995-11-18       854.0           7.8
# 949                             Heat   1995-12-15      1886.0           7.7
# 9702                  Bound by Honor   1993-02-05       116.0           7.7
# 280       Terminator 2: Judgment Day   1991-07-01      4274.0           7.7
# ...                              ...          ...         ...           ...
# 10366  Universal Soldier: The Return   1999-08-05       138.0           4.2
# 1639         Speed 2: Cruise Control   1997-06-13       439.0           4.1
# 11667                 Street Fighter   1994-12-22       330.0           4.1
# 11867                      Barb Wire   1996-05-02       117.0           3.9
# 9823     Mortal Kombat: Annihilation   1997-11-21       225.0           3.8
#
# [250 rows x 4 columns]

# %%
df.production_companies
# Out:
# id
# 862                                 Pixar Animation Studios
# 8844      TriStar Pictures|Teitler Film|Interscope Commu...
# 15602                           Warner Bros.|Lancaster Gate
# 31357                Twentieth Century Fox Film Corporation
# 11862             Sandollar Productions|Touchstone Pictures
#                                 ...
# 439050                                                  NaN
# 111109                                          Sine Olivia
# 67758                               American World Pictures
# 227506                                            Yermoliev
# 461257                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
production = df.production_companies.str.split('|',expand=True)
production
# Out:
#                                             0                    1   \
# id
# 862                    Pixar Animation Studios                 None
# 8844                          TriStar Pictures         Teitler Film
# 15602                             Warner Bros.       Lancaster Gate
# 31357   Twentieth Century Fox Film Corporation                 None
# 11862                    Sandollar Productions  Touchstone Pictures
# ...                                        ...                  ...
# 439050                                     NaN                  NaN
# 111109                             Sine Olivia                 None
# 67758                  American World Pictures                 None
# 227506                               Yermoliev                 None
# 461257                                     NaN                  NaN
#
#                                2     3     4     5     6     7     8     9   \
# id
# ...

# %%
production.stack().reset_index(level = 1,drop = True).to_frame()
# Out:
#                                     0
# id
# 862           Pixar Animation Studios
# 8844                 TriStar Pictures
# 8844                     Teitler Film
# 8844        Interscope Communications
# 15602                    Warner Bros.
# ...                               ...
# 30840     20th Century Fox Television
# 30840   CanWest Global Communications
# 111109                    Sine Olivia
# 67758         American World Pictures
# 227506                      Yermoliev
#
# [70029 rows x 1 columns]

# %%
production = production.stack().reset_index(level = 1,drop = True).to_frame()

# %%
production.columns = ['Production Companies']

# %%
production
# Out:
#                  Production Companies
# id
# 862           Pixar Animation Studios
# 8844                 TriStar Pictures
# 8844                     Teitler Film
# 8844        Interscope Communications
# 15602                    Warner Bros.
# ...                               ...
# 30840     20th Century Fox Television
# 30840   CanWest Global Communications
# 111109                    Sine Olivia
# 67758         American World Pictures
# 227506                      Yermoliev
#
# [70029 rows x 1 columns]

# %%
production = production.merge(df[['title','revenue_musd','vote_average','popularity']],
               how='left',left_index=True,right_index=True)

# %%
production
# Out:
#                  Production Companies                title  revenue_musd  \
# id
# 862           Pixar Animation Studios            Toy Story    373.554033
# 8844                 TriStar Pictures              Jumanji    262.797249
# 8844                     Teitler Film              Jumanji    262.797249
# 8844        Interscope Communications              Jumanji    262.797249
# 15602                    Warner Bros.     Grumpier Old Men           NaN
# ...                               ...                  ...           ...
# 30840     20th Century Fox Television           Robin Hood           NaN
# 30840   CanWest Global Communications           Robin Hood           NaN
# 111109                    Sine Olivia  Century of Birthing           NaN
# 67758         American World Pictures             Betrayal           NaN
# 227506                      Yermoliev     Satan Triumphant           NaN
#
#         vote_average  popularity
# id
# 862              7.7   21.946943
# ...

# %%
production['Production Companies'].value_counts().head(20)
# Out:
# Production Companies
# Warner Bros.                                   1248
# Metro-Goldwyn-Mayer (MGM)                      1073
# Paramount Pictures                              996
# Twentieth Century Fox Film Corporation          834
# Universal Pictures                              827
# Columbia Pictures Corporation                   447
# Canal+                                          433
# Columbia Pictures                               429
# RKO Radio Pictures                              290
# United Artists                                  276
# New Line Cinema                                 276
# Walt Disney Pictures                            262
# Touchstone Pictures                             224
# TriStar Pictures                                197
# Mosfilm                                         186
# Miramax Films                                   182
# France 2 Cinéma                                 167
# Centre National de la Cinématographie (CNC)     160
# ...

# %%
agg = production.groupby('Production Companies').agg(Total_Revenue = ('revenue_musd','sum'),
                               Mean_Average = ('revenue_musd','mean'),
                               Mean_Rating = ('vote_average','mean'),
                               Mean_Pop = ('popularity','mean'),
                               Total_Movies = ('Production Companies','count'))

# %%
agg.Total_Revenue.nlargest(20)
# Out:
# Production Companies
# Warner Bros.                              63525.187272
# Universal Pictures                        55259.190410
# Paramount Pictures                        48769.399614
# Twentieth Century Fox Film Corporation    47687.746332
# Walt Disney Pictures                      40837.270159
# Columbia Pictures                         32279.735705
# New Line Cinema                           22173.391499
# Amblin Entertainment                      17343.720181
# DreamWorks SKG                            15475.754744
# Dune Entertainment                        15003.789066
# Village Roadshow Pictures                 14904.700343
# Relativity Media                          14603.149665
# Touchstone Pictures                       14121.784861
# DreamWorks Animation                      13707.515604
# Legendary Pictures                        13468.663007
# Metro-Goldwyn-Mayer (MGM)                 12376.790071
# Marvel Studios                            11699.635216
# ...

# %%
agg
# Out:
#                                  Total_Revenue  Mean_Average  Mean_Rating  \
# Production Companies
#  Movie Studios                        0.000000           NaN          5.5
# "DIA" Productions GmbH & Co. KG      44.350926     44.350926          5.8
# # Andrea Sperling Productions         0.000000           NaN          5.7
# # Lexyn Productions                   0.000000           NaN          6.3
# 'A' Production Committee              0.000000           NaN          NaN
# ...                                        ...           ...          ...
# 영화사 집                                 0.000000           NaN          7.0
# 이디오플랜                                 0.000000           NaN          6.9
# 인벤트 디                                 0.000000           NaN          6.9
# 타임스토리그룹                               0.000000           NaN          6.5
# 프로덕션M                                 0.000000           NaN          6.2
#
#                                   Mean_Pop  Total_Movies
# ...

# %%
agg = agg[agg.Total_Movies>10]

# %%
agg
# Out:
#                                      Total_Revenue  Mean_Average  Mean_Rating  \
# Production Companies
# 120dB Films                               1.206313      0.402104     5.654545
# 1492 Pictures                          5470.573905    321.798465     6.200000
# 20th Century Fox Home Entertainment      17.280326     17.280326     5.344444
# 20th Century Fox Television              42.000000     42.000000     5.731579
# 21 Laps Entertainment                  2673.526504    178.235100     6.200000
# ...                                            ...           ...          ...
# Zespól Filmowy "Kadr"                     0.000000           NaN     7.220000
# Zweites Deutsches Fernsehen (ZDF)       269.894221     24.535838     6.461702
# uFilm                                   303.131749     37.891469     5.830435
# Österreichischer Rundfunk (ORF)          92.192304     30.730768     6.546154
# Česká televize                            0.000000           NaN     6.300000
#
# ...

# %%
agg.Total_Revenue.nlargest(20)
# Out:
# Production Companies
# Warner Bros.                              63525.187272
# Universal Pictures                        55259.190410
# Paramount Pictures                        48769.399614
# Twentieth Century Fox Film Corporation    47687.746332
# Walt Disney Pictures                      40837.270159
# Columbia Pictures                         32279.735705
# New Line Cinema                           22173.391499
# Amblin Entertainment                      17343.720181
# DreamWorks SKG                            15475.754744
# Dune Entertainment                        15003.789066
# Village Roadshow Pictures                 14904.700343
# Relativity Media                          14603.149665
# Touchstone Pictures                       14121.784861
# DreamWorks Animation                      13707.515604
# Legendary Pictures                        13468.663007
# Metro-Goldwyn-Mayer (MGM)                 12376.790071
# Marvel Studios                            11699.635216
# ...

# %%
agg.Mean_Average.nlargest(20)
# Out:
# Production Companies
# Illumination Entertainment         716.470739
# Pixar Animation Studios            621.585207
# Marvel Studios                     615.770275
# Heyday Films                       609.231721
# WingNut Films                      547.000334
# Revolution Sun Studios             541.355948
# Fuji Television Network            490.036977
# Blue Sky Studios                   479.457046
# Walt Disney Animation Studios      465.623977
# Lucasfilm                          449.928232
# Bad Robot                          439.815813
# Twentieth Century Fox Animation    428.636088
# DreamWorks Animation               403.162224
# Moving Picture Company (MPC)       400.213901
# DC Entertainment                   388.288039
# Dentsu                             380.733633
# Jerry Bruckheimer Films            373.226711
# Bad Hat Harry Productions          367.476851
# Temple Hill Entertainment          359.980605
# Centropolis Entertainment          344.863637
# ...

# %%
agg.Mean_Rating.nlargest(20)
# Out:
# Production Companies
# Cineriz                           7.435714
# Studio Ghibli                     7.350000
# The Criterion Collection          7.269231
# Zespól Filmowy "Kadr"             7.220000
# ZDF                               7.211111
# Office Kitano                     7.192308
# Passion Pictures                  7.191667
# Argos Films                       7.166667
# Pixar Animation Studios           7.125000
# Les Films du Carrosse             7.112500
# WingNut Films                     7.106250
# Kadokawa Shoten Publishing Co.    7.100000
# Walt Disney Animation Studios     7.100000
# Heyday Films                      7.077778
# Kodansha                          7.073333
# Bandai Visual Company             7.062500
# CNC                               7.054545
# HBO Documentary Films             7.053333
# HBO                               7.052381
# Netflix                           7.050000
# Name: Mean_Rating, dtype: float64

# %%
agg.Total_Movies.nlargest(20)
# Out:
# Production Companies
# Warner Bros.                                   1248
# Metro-Goldwyn-Mayer (MGM)                      1073
# Paramount Pictures                              996
# Twentieth Century Fox Film Corporation          834
# Universal Pictures                              827
# Columbia Pictures Corporation                   447
# Canal+                                          433
# Columbia Pictures                               429
# RKO Radio Pictures                              290
# New Line Cinema                                 276
# United Artists                                  276
# Walt Disney Pictures                            262
# Touchstone Pictures                             224
# TriStar Pictures                                197
# Mosfilm                                         186
# Miramax Films                                   182
# France 2 Cinéma                                 167
# Centre National de la Cinématographie (CNC)     160
# ...

# %%
df.genres
# Out:
# id
# 862        Animation|Comedy|Family
# 8844      Adventure|Fantasy|Family
# 15602               Romance|Comedy
# 31357         Comedy|Drama|Romance
# 11862                       Comedy
#                     ...
# 439050                Drama|Family
# 111109                       Drama
# 67758        Action|Drama|Thriller
# 227506                         NaN
# 461257                         NaN
# Name: genres, Length: 44691, dtype: object

# %%
genres = df.genres.str.split('|',expand=True)
genres
# Out:
#                 0        1         2     3     4     5     6     7
# id
# 862     Animation   Comedy    Family  None  None  None  None  None
# 8844    Adventure  Fantasy    Family  None  None  None  None  None
# 15602     Romance   Comedy      None  None  None  None  None  None
# 31357      Comedy    Drama   Romance  None  None  None  None  None
# 11862      Comedy     None      None  None  None  None  None  None
# ...           ...      ...       ...   ...   ...   ...   ...   ...
# 439050      Drama   Family      None  None  None  None  None  None
# 111109      Drama     None      None  None  None  None  None  None
# 67758      Action    Drama  Thriller  None  None  None  None  None
# 227506        NaN      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 461257        NaN      NaN       NaN   NaN   NaN   NaN   NaN   NaN
#
# [44691 rows x 8 columns]

# %%
genres = genres.stack().reset_index(level = 1,drop = True).to_frame()

# %%
genres.columns = ['Genres']

# %%
genres = genres.merge(df[['title','revenue_musd','vote_average','popularity']],
               how='left',left_index=True,right_index=True)
genres
# Out:
#            Genres                title  revenue_musd  vote_average  popularity
# id
# 862     Animation            Toy Story    373.554033           7.7   21.946943
# 862        Comedy            Toy Story    373.554033           7.7   21.946943
# 862        Family            Toy Story    373.554033           7.7   21.946943
# 8844    Adventure              Jumanji    262.797249           6.9   17.015539
# 8844      Fantasy              Jumanji    262.797249           6.9   17.015539
# ...           ...                  ...           ...           ...         ...
# 439050     Family               Subdue           NaN           4.0    0.072051
# 111109      Drama  Century of Birthing           NaN           9.0    0.178241
# 67758      Action             Betrayal           NaN           3.8    0.903007
# 67758       Drama             Betrayal           NaN           3.8    0.903007
# 67758    Thriller             Betrayal           NaN           3.8    0.903007
#
# ...

# %%
genres.Genres.value_counts().head(20)
# Out:
# Genres
# Drama              20054
# Comedy             13067
# Thriller            7565
# Romance             6662
# Action              6542
# Horror              4634
# Crime               4282
# Documentary         3867
# Adventure           3468
# Science Fiction     3013
# Family              2740
# Mystery             2453
# Fantasy             2290
# Animation           1911
# Music               1587
# Foreign             1586
# History             1391
# War                 1317
# Western             1038
# TV Movie             758
# Name: count, dtype: int64

# %%
agg = genres.groupby('Genres').agg(Total_Revenue = ('revenue_musd','sum'),
                               Mean_Average = ('revenue_musd','mean'),
                               Mean_Rating = ('vote_average','mean'),
                               Mean_Pop = ('popularity','mean'),
                               Total_Movies = ('Genres','count'))

# %%
agg
# Out:
#                  Total_Revenue  Mean_Average  Mean_Rating  Mean_Pop  \
# Genres
# Action           201388.050019    116.073804     5.751367  4.783477
# Adventure        199978.669360    179.192356     5.881421  6.003722
# Animation         67432.971320    176.989426     6.448148  4.747663
# Comedy           166845.045970     64.097213     5.967845  3.248691
# Crime             63375.730411     58.518680     6.100048  4.154379
# Documentary        1449.112153      6.647303     6.656970  0.956166
# Drama            160754.363574     43.826162     6.173677  3.029791
# Family           107076.778493    159.103683     5.933220  4.765833
# Fantasy          103920.152145    166.006633     5.929336  5.361045
# Foreign             291.536311      3.512486     5.972989  0.768672
# History           14902.198420     50.515927     6.412481  3.477655
# Horror            30837.094673     41.955231     5.312182  3.581489
# Music             13370.292367     50.076001     6.331772  2.558967
# ...

# %%
agg.nlargest(10,'Total_Revenue')
# Out:
#                  Total_Revenue  Mean_Average  Mean_Rating  Mean_Pop  \
# Genres
# Action           201388.050019    116.073804     5.751367  4.783477
# Adventure        199978.669360    179.192356     5.881421  6.003722
# Comedy           166845.045970     64.097213     5.967845  3.248691
# Drama            160754.363574     43.826162     6.173677  3.029791
# Thriller         129724.552970     69.520125     5.738379  4.506756
# Family           107076.778493    159.103683     5.933220  4.765833
# Fantasy          103920.152145    166.006633     5.929336  5.361045
# Science Fiction   97847.960421    131.516076     5.476052  4.999308
# Romance           73473.190426     51.272289     6.036092  3.143989
# Animation         67432.971320    176.989426     6.448148  4.747663
#
#                  Total_Movies
# Genres
# Action                   6542
# Adventure                3468
# Comedy                  13067
# Drama                   20054
# Thriller                 7565
# ...

# %%
agg.nlargest(10,'Mean_Rating')
# Out:
#              Total_Revenue  Mean_Average  Mean_Rating  Mean_Pop  Total_Movies
# Genres
# Documentary    1449.112153      6.647303     6.656970  0.956166          3867
# Animation     67432.971320    176.989426     6.448148  4.747663          1911
# History       14902.198420     50.515927     6.412481  3.477655          1391
# Music         13370.292367     50.076001     6.331772  2.558967          1587
# War           15910.458263     65.475137     6.285647  3.345644          1317
# Drama        160754.363574     43.826162     6.173677  3.029791         20054
# Crime         63375.730411     58.518680     6.100048  4.154379          4282
# Romance       73473.190426     51.272289     6.036092  3.143989          6662
# Foreign         291.536311      3.512486     5.972989  0.768672          1586
# Comedy       166845.045970     64.097213     5.967845  3.248691         13067

# %%
agg.nlargest(10,'Mean_Pop')
# Out:
#                  Total_Revenue  Mean_Average  Mean_Rating  Mean_Pop  \
# Genres
# Adventure        199978.669360    179.192356     5.881421  6.003722
# Fantasy          103920.152145    166.006633     5.929336  5.361045
# Science Fiction   97847.960421    131.516076     5.476052  4.999308
# Action           201388.050019    116.073804     5.751367  4.783477
# Family           107076.778493    159.103683     5.933220  4.765833
# Animation         67432.971320    176.989426     6.448148  4.747663
# Thriller         129724.552970     69.520125     5.738379  4.506756
# Crime             63375.730411     58.518680     6.100048  4.154379
# Mystery           34754.614989     63.190209     5.960559  3.974673
# Horror            30837.094673     41.955231     5.312182  3.581489
#
#                  Total_Movies
# Genres
# Adventure                3468
# Fantasy                  2290
# Science Fiction          3013
# Action                   6542
# Family                   2740
# ...

# %%
agg.nlargest(10,'Total_Movies')
# Out:
#                  Total_Revenue  Mean_Average  Mean_Rating  Mean_Pop  \
# Genres
# Drama            160754.363574     43.826162     6.173677  3.029791
# Comedy           166845.045970     64.097213     5.967845  3.248691
# Thriller         129724.552970     69.520125     5.738379  4.506756
# Romance           73473.190426     51.272289     6.036092  3.143989
# Action           201388.050019    116.073804     5.751367  4.783477
# Horror            30837.094673     41.955231     5.312182  3.581489
# Crime             63375.730411     58.518680     6.100048  4.154379
# Documentary        1449.112153      6.647303     6.656970  0.956166
# Adventure        199978.669360    179.192356     5.881421  6.003722
# Science Fiction   97847.960421    131.516076     5.476052  4.999308
#
#                  Total_Movies
# Genres
# Drama                   20054
# Comedy                  13067
# Thriller                 7565
# Romance                  6662
# Action                   6542
# ...
